# %% [markdown]
# # Rechunk variables
# This notebook rechunks variables for optimizing operations across the time dimension.

# %%
__author__ = "@andrewbrettin"

# %%
import os
import sys
import shutil
import warnings
import json
from datetime import datetime
from itertools import product
import numpy as np
import xarray as xr
from rechunker import rechunk
import dask
from dask_jobqueue import PBSCluster
from dask.distributed import Client

sys.path.append('..')
import utils

# %%
## Globals
with open("../paths.json") as paths_json: 
    PATHS = json.load(paths_json)
with open("../globals.json") as globals_json:
    GLOBALS = json.load(globals_json)
    
FILE  = os.path.join(os.path.abspath('.'), 'rechunk.ipynb')

VARIABLES = ['zos', 'SST', 'UBOT', 'VBOT']

# %% [markdown]
# Dask

# %%
cluster = PBSCluster(walltime='02:30:00')
client = Client(cluster)

# %%
cluster.scale(4)
cluster
# Out:
# PBSCluster(a3d2edf6, 'tcp://10.12.206.60:32955', workers=0, threads=0, memory=0 B)

# %%
client.dashboard_link
# Out:
# 'https://jupyterhub.hpc.ucar.edu/stable/user/abrettin/proxy/8787/status'

# %% [markdown]
# Functions

# %%
def rm_stores(*stores):
    for store in stores:
        if os.path.exists(store):
            shutil.rmtree(store)

def execute_rechunk(ds, target_store, temp_store):
    chunks_dict = {
        'time': -1,
        'lat': 48,
        'lon': 48
    }
    max_mem='8GB'
    
    array_plan = rechunk(
        ds, chunks_dict, max_mem, target_store, temp_store=temp_store
    )
    
    array_plan.execute()

# %%
def main():
    START_TIME = datetime.now()
    
    for var, init_year, member in product(
            VARIABLES, GLOBALS['init_years'], GLOBALS['members']):
        print(f"LE-{init_year}.{member}.{var}")
        print(datetime.now() - START_TIME)
        
        # Load data as a dataset
        array = utils.data.load_dataset(
            var, init_year, member, chunkedby='space')
        ds = xr.Dataset({var: array})
        ds = ds.chunk({'time': 3650})
        
        # Prepare paths for rechunking
        print("Preparing zarr stores")
        print(datetime.now() - START_TIME)
        target_store = os.path.join(
            PATHS['rechunked'],
            f'LE2-{init_year}.{member}.{var}_rechunked.zarr'
        )
        temp_store = os.path.join(PATHS['tmp'],'temp.zarr')
        rm_stores(target_store, temp_store)
        
        # Rechunk
        print("Rechunking")
        print(datetime.now() - START_TIME)
        execute_rechunk(ds, target_store, temp_store)
        
        # Repeat
        print(f"Completed rechunk for LE-{init_year}.{member}.{var}")
        print(datetime.now() - START_TIME, '\n')
        client.restart()
    
    print("PROCESS_COMPLETED")
    print(START_TIME - datetime.now())
    
    return 0

# %% [markdown]
# ---

# %%
main()
# Out:
# LE-1251.011.SSH
# 0:00:00.000035
# Preparing zarr stores
# 0:00:00.736510
# Rechunking
# 0:00:00.738820
# Completed rechunk for LE-1251.011.SSH
# 0:01:10.371643
#
# LE-1251.012.SSH
# 0:01:14.713106
# Preparing zarr stores
# 0:01:15.202158
# Rechunking
# 0:01:15.603567
# Completed rechunk for LE-1251.012.SSH
# 0:02:20.351156
#
# LE-1251.013.SSH
# 0:02:23.564562
# Preparing zarr stores
# 0:02:24.110935
# Rechunking
# 0:02:24.560562
# Completed rechunk for LE-1251.013.SSH
# 0:03:22.068667
#
# LE-1281.011.SSH
# 0:03:25.281665
# Preparing zarr stores
# 0:03:25.820717
# Rechunking
# 0:03:26.244054
# Completed rechunk for LE-1281.011.SSH
# 0:04:33.149712
#
# LE-1281.012.SSH
# 0:04:36.161316
# Preparing zarr stores
# 0:04:36.639374
# Rechunking
# 0:04:37.084018
# Completed rechunk for LE-1281.012.SSH
# 0:05:44.906164
#
# LE-1281.013.SSH
# 0:05:48.346723
# Preparing zarr stores
# 0:05:48.877961
# Rechunking
# 0:05:49.293081
# Completed rechunk for LE-1281.013.SSH
# 0:06:44.157413
#
# LE-1301.011.SSH
# 0:06:47.580025
# Preparing zarr stores
# 0:06:48.122607
# Rechunking
# 0:06:48.499406
# Completed rechunk for LE-1301.011.SSH
# 0:07:41.956433
#
# LE-1301.012.SSH
# 0:07:45.394640
# Preparing zarr stores
# 0:07:45.869775
# Rechunking
# 0:07:46.316651
# Completed rechunk for LE-1301.012.SSH
# 0:08:53.996698
#
# LE-1301.013.SSH
# 0:08:57.198598
# Preparing zarr stores
# 0:08:57.695956
# Rechunking
# 0:08:58.133264
# Completed rechunk for LE-1301.013.SSH
# 0:10:03.922892
#
# LE-1251.011.zos
# 0:10:07.125286
# Preparing zarr stores
# 0:10:07.604562
# Rechunking
# 0:10:08.071623
# Completed rechunk for LE-1251.011.zos
# 0:11:00.142019
#
# LE-1251.012.zos
# 0:11:03.567976
# Preparing zarr stores
# 0:11:03.954410
# Rechunking
# 0:11:04.385786
# Completed rechunk for LE-1251.012.zos
# 0:12:07.547810
#
# LE-1251.013.zos
# 0:12:10.763984
# Preparing zarr stores
# 0:12:11.124598
# Rechunking
# 0:12:11.482697
# Completed rechunk for LE-1251.013.zos
# 0:13:03.422685
#
# LE-1281.011.zos
# 0:13:06.628615
# Preparing zarr stores
# 0:13:07.122222
# Rechunking
# 0:13:07.492912
# Completed rechunk for LE-1281.011.zos
# 0:13:59.790074
#
# LE-1281.012.zos
# 0:14:03.013876
# Preparing zarr stores
# 0:14:03.482179
# Rechunking
# 0:14:03.884695
# Completed rechunk for LE-1281.012.zos
# 0:15:10.092490
#
# LE-1281.013.zos
# 0:15:13.307734
# Preparing zarr stores
# 0:15:13.859990
# Rechunking
# 0:15:14.326537
# Completed rechunk for LE-1281.013.zos
# 0:16:19.732121
#
# LE-1301.011.zos
# 0:16:23.141446
# Preparing zarr stores
# 0:16:23.681424
# Rechunking
# 0:16:24.134030
# Completed rechunk for LE-1301.011.zos
# 0:17:16.158341
#
# LE-1301.012.zos
# 0:17:19.585172
# Preparing zarr stores
# 0:17:20.157461
# Rechunking
# 0:17:20.629904
# Completed rechunk for LE-1301.012.zos
# 0:18:14.279926
#
# LE-1301.013.zos
# 0:18:17.492400
# Preparing zarr stores
# 0:18:18.021605
# Rechunking
# 0:18:18.488849
# Completed rechunk for LE-1301.013.zos
# 0:19:23.978693
#
# LE-1251.011.SST
# 0:19:27.197108
# Preparing zarr stores
# 0:19:27.865779
# Rechunking
# 0:19:28.268224
# Completed rechunk for LE-1251.011.SST
# 0:20:07.681366
#
# LE-1251.012.SST
# 0:20:10.689534
# Preparing zarr stores
# 0:20:11.177866
# Rechunking
# 0:20:11.441275
# Completed rechunk for LE-1251.012.SST
# 0:20:53.272635
#
# LE-1251.013.SST
# 0:20:56.488916
# Preparing zarr stores
# 0:20:56.983181
# Rechunking
# 0:20:57.243307
# Completed rechunk for LE-1251.013.SST
# 0:21:38.123474
#
# LE-1281.011.SST
# 0:21:41.138467
# Preparing zarr stores
# 0:21:41.756293
# Rechunking
# 0:21:41.975017
# Completed rechunk for LE-1281.011.SST
# 0:22:21.924726
#
# LE-1281.012.SST
# 0:22:24.739317
# Preparing zarr stores
# 0:22:25.350255
# Rechunking
# 0:22:25.574931
# Completed rechunk for LE-1281.012.SST
# 0:23:08.567004
#
# LE-1281.013.SST
# 0:23:11.434298
# Preparing zarr stores
# 0:23:12.074907
# Rechunking
# 0:23:12.319094
# Completed rechunk for LE-1281.013.SST
# 0:23:52.461733
#
# LE-1301.011.SST
# 0:23:55.669239
# Preparing zarr stores
# 0:23:56.249206
# Rechunking
# 0:23:56.486516
# Completed rechunk for LE-1301.011.SST
# 0:24:38.674129
#
# LE-1301.012.SST
# 0:24:41.275165
# Preparing zarr stores
# 0:24:41.679838
# Rechunking
# 0:24:41.908313
# Completed rechunk for LE-1301.012.SST
# 0:25:22.953142
#
# LE-1301.013.SST
# 0:25:26.404698
# Preparing zarr stores
# 0:25:27.106768
# Rechunking
# 0:25:27.349937
# Completed rechunk for LE-1301.013.SST
# 0:26:09.481047
#
# LE-1251.011.PSL
# 0:26:11.695220
# Preparing zarr stores
# 0:26:17.195823
# Rechunking
# 0:26:17.413524
# Completed rechunk for LE-1251.011.PSL
# 0:28:40.931254
#
# LE-1251.012.PSL
# 0:28:43.853495
# Preparing zarr stores
# 0:28:48.964855
# Rechunking
# 0:28:49.171995
# Completed rechunk for LE-1251.012.PSL
# 0:31:10.927570
#
# LE-1251.013.PSL
# 0:31:13.652319
# Preparing zarr stores
# 0:31:19.005438
# Rechunking
# 0:31:19.249523
# Completed rechunk for LE-1251.013.PSL
# 0:33:39.857022
#
# LE-1281.011.PSL
# 0:33:42.588777
# Preparing zarr stores
# 0:33:47.890038
# Rechunking
# 0:33:48.098044
# Completed rechunk for LE-1281.011.PSL
# 0:36:13.261618
#
# LE-1281.012.PSL
# 0:36:16.154760
# Preparing zarr stores
# 0:36:21.303924
# Rechunking
# 0:36:21.510939
# Completed rechunk for LE-1281.012.PSL
# 0:38:46.895617
#
# LE-1281.013.PSL
# 0:38:49.592709
# Preparing zarr stores
# 0:38:54.390485
# Rechunking
# 0:38:54.612923
# Completed rechunk for LE-1281.013.PSL
# 0:41:16.419587
#
# LE-1301.011.PSL
# 0:41:18.901203
# Preparing zarr stores
# 0:41:24.157587
# Rechunking
# 0:41:24.365818
# Completed rechunk for LE-1301.011.PSL
# 0:43:48.175474
#
# LE-1301.012.PSL
# 0:43:51.076414
# Preparing zarr stores
# 0:43:56.434066
# Rechunking
# 0:43:56.683645
# Completed rechunk for LE-1301.012.PSL
# 0:46:20.906690
#
# LE-1301.013.PSL
# 0:46:23.447668
# Preparing zarr stores
# 0:46:28.223244
# Rechunking
# 0:46:28.453523
# Completed rechunk for LE-1301.013.PSL
# 0:48:53.729965
#
# LE-1251.011.UBOT
# 0:48:56.248502
# Preparing zarr stores
# 0:49:02.336711
# Rechunking
# 0:49:02.546563
# Completed rechunk for LE-1251.011.UBOT
# 0:51:29.097006
#
# LE-1251.012.UBOT
# 0:51:31.999931
# Preparing zarr stores
# 0:51:43.645512
# Rechunking
# 0:51:43.851870
# Completed rechunk for LE-1251.012.UBOT
# 0:54:20.580116
#
# LE-1251.013.UBOT
# 0:54:23.653639
# Preparing zarr stores
# 0:54:30.839942
# Rechunking
# 0:54:31.071122
# Completed rechunk for LE-1251.013.UBOT
# 0:57:02.276334
#
# LE-1281.011.UBOT
# 0:57:04.755534
# Preparing zarr stores
# 0:57:10.558462
# Rechunking
# 0:57:10.789916
# Completed rechunk for LE-1281.011.UBOT
# 0:59:40.799126
#
# LE-1281.012.UBOT
# 0:59:43.502121
# Preparing zarr stores
# 0:59:49.214378
# Rechunking
# 0:59:49.423410
# Completed rechunk for LE-1281.012.UBOT
# 1:02:19.473636
#
# LE-1281.013.UBOT
# 1:02:22.800855
# Preparing zarr stores
# 1:02:28.577627
# Rechunking
# 1:02:28.807575
# Completed rechunk for LE-1281.013.UBOT
# 1:04:54.901662
#
# LE-1301.011.UBOT
# 1:04:58.218552
# Preparing zarr stores
# 1:05:04.055783
# Rechunking
# 1:05:04.265544
# Completed rechunk for LE-1301.011.UBOT
# 1:07:29.800483
#
# LE-1301.012.UBOT
# 1:07:32.925706
# Preparing zarr stores
# 1:07:38.360233
# Rechunking
# 1:07:38.576322
# Completed rechunk for LE-1301.012.UBOT
# 1:10:04.404220
#
# LE-1301.013.UBOT
# 1:10:07.673326
# Preparing zarr stores
# 1:10:13.372029
# Rechunking
# 1:10:13.590042
# Completed rechunk for LE-1301.013.UBOT
# 1:12:41.569031
#
# LE-1251.011.VBOT
# 1:12:44.898785
# Preparing zarr stores
# 1:12:50.761963
# Rechunking
# 1:12:51.006657
# Completed rechunk for LE-1251.011.VBOT
# 1:15:15.596497
#
# LE-1251.012.VBOT
# 1:15:18.982287
# Preparing zarr stores
# 1:15:24.765571
# Rechunking
# 1:15:25.008305
# Completed rechunk for LE-1251.012.VBOT
# 1:17:49.151954
#
# LE-1251.013.VBOT
# 1:17:52.272220
# Preparing zarr stores
# 1:17:58.866715
# Rechunking
# 1:17:59.104784
# Completed rechunk for LE-1251.013.VBOT
# 1:20:23.182914
#
# LE-1281.011.VBOT
# 1:20:26.700054
# Preparing zarr stores
# 1:20:32.805816
# Rechunking
# 1:20:33.031985
# Completed rechunk for LE-1281.011.VBOT
# 1:23:01.276394
#
# LE-1281.012.VBOT
# 1:23:05.003299
# Preparing zarr stores
# 1:23:11.070098
# Rechunking
# 1:23:11.281675
# Completed rechunk for LE-1281.012.VBOT
# 1:25:35.911123
#
# LE-1281.013.VBOT
# 1:25:39.445785
# Preparing zarr stores
# 1:25:45.578216
# Rechunking
# 1:25:45.791752
# Completed rechunk for LE-1281.013.VBOT
# 1:28:09.082463
#
# LE-1301.011.VBOT
# 1:28:12.396478
# Preparing zarr stores
# 1:28:18.353383
# Rechunking
# 1:28:18.577871
# Completed rechunk for LE-1301.011.VBOT
# 1:30:45.562819
#
# LE-1301.012.VBOT
# 1:30:48.890329
# Preparing zarr stores
# 1:30:54.807210
# Rechunking
# 1:30:55.004004
# Completed rechunk for LE-1301.012.VBOT
# 1:33:20.142722
#
# LE-1301.013.VBOT
# 1:33:24.901456
# Preparing zarr stores
# 1:33:30.682753
# Rechunking
# 1:33:30.943816
# Completed rechunk for LE-1301.013.VBOT
# 1:35:55.797201
#
# LE-1251.011.SHFLX
# 1:35:59.117027
# Preparing zarr stores
# 1:36:05.922952
# Rechunking
# 1:36:06.150255
# Completed rechunk for LE-1251.011.SHFLX
# 1:38:42.446381
#
# LE-1251.012.SHFLX
# 1:38:45.964610
# Preparing zarr stores
# 1:38:51.846178
# Rechunking
# 1:38:52.044091
# Completed rechunk for LE-1251.012.SHFLX
# 1:41:27.300137
#
# LE-1251.013.SHFLX
# 1:41:30.430783
# Preparing zarr stores
# 1:41:36.474341
# Rechunking
# 1:41:36.670199
# Completed rechunk for LE-1251.013.SHFLX
# 1:44:07.379387
#
# LE-1281.011.SHFLX
# 1:44:09.904590
# Preparing zarr stores
# 1:44:15.718089
# Rechunking
# 1:44:16.009943
# Completed rechunk for LE-1281.011.SHFLX
# 1:46:48.759422
#
# LE-1281.012.SHFLX
# 1:46:52.259019
# Preparing zarr stores
# 1:46:58.244786
# Rechunking
# 1:46:58.477404
# Completed rechunk for LE-1281.012.SHFLX
# 1:49:30.875095
#
# LE-1281.013.SHFLX
# 1:49:33.789894
# Preparing zarr stores
# 1:49:39.758645
# Rechunking
# 1:49:39.981759
# Completed rechunk for LE-1281.013.SHFLX
# 1:52:11.757996
#
# LE-1301.011.SHFLX
# 1:52:14.684759
# Preparing zarr stores
# 1:52:20.819991
# Rechunking
# 1:52:20.994799
# Completed rechunk for LE-1301.011.SHFLX
# 1:54:53.474031
#
# LE-1301.012.SHFLX
# 1:54:56.790323
# Preparing zarr stores
# 1:55:02.203196
# Rechunking
# 1:55:02.364342
# Completed rechunk for LE-1301.012.SHFLX
# 1:57:35.804463
#
# LE-1301.013.SHFLX
# 1:57:39.125745
# Preparing zarr stores
# 1:57:45.207081
# Rechunking
# 1:57:45.388269

# %%
main()
# Out:
# LE-1251.011.SHF
# 0:00:00.000146
# Preparing zarr stores
# 0:00:00.588535
# Rechunking
# 0:00:00.590744
# Completed rechunk for LE-1251.011.SHF
# 0:01:39.553802
#
# LE-1251.012.SHF
# 0:01:45.488998
# Preparing zarr stores
# 0:01:45.909732
# Rechunking
# 0:01:46.128323
# Completed rechunk for LE-1251.012.SHF
# 0:02:53.752917
#
# LE-1251.013.SHF
# 0:02:57.712715
# Preparing zarr stores
# 0:02:58.337886
# Rechunking
# 0:02:58.533433
# Completed rechunk for LE-1251.013.SHF
# 0:04:09.235987
#
# LE-1281.011.SHF
# 0:04:13.609861
# Preparing zarr stores
# 0:04:14.270614
# Rechunking
# 0:04:14.476724
# Completed rechunk for LE-1281.011.SHF
# 0:05:25.026887
#
# LE-1281.012.SHF
# 0:05:29.387913
# Preparing zarr stores
# 0:05:29.810244
# Rechunking
# 0:05:29.997003
# Completed rechunk for LE-1281.012.SHF
# 0:06:38.890103
#
# LE-1281.013.SHF
# 0:06:43.244344
# Preparing zarr stores
# 0:06:43.855556
# Rechunking
# 0:06:44.047950
# Completed rechunk for LE-1281.013.SHF
# 0:07:56.222396
#
# LE-1301.011.SHF
# 0:08:00.372004
# Preparing zarr stores
# 0:08:01.020692
# Rechunking
# 0:08:01.242468
# Completed rechunk for LE-1301.011.SHF
# 0:09:16.672753
#
# LE-1301.012.SHF
# 0:09:21.038553
# Preparing zarr stores
# 0:09:21.467624
# Rechunking
# 0:09:21.657979
# Completed rechunk for LE-1301.012.SHF
# 0:10:33.647901
#
# LE-1301.013.SHF
# 0:10:38.016217
# Preparing zarr stores
# 0:10:38.738687
# Rechunking
# 0:10:38.972373
# Completed rechunk for LE-1301.013.SHF
# 0:11:51.421557
#
# LE-1251.011.MLD
# 0:11:55.819990
# Preparing zarr stores
# 0:11:56.443767
# Rechunking
# 0:11:56.679471
# Completed rechunk for LE-1251.011.MLD
# 0:13:06.252586
#
# LE-1251.012.MLD
# 0:13:10.614307
# Preparing zarr stores
# 0:13:11.041694
# Rechunking
# 0:13:11.255010
# Completed rechunk for LE-1251.012.MLD
# 0:14:21.468293
#
# LE-1251.013.MLD
# 0:14:25.449034
# Preparing zarr stores
# 0:14:26.160320
# Rechunking
# 0:14:26.374704
# Completed rechunk for LE-1251.013.MLD
# 0:15:34.227662
#
# LE-1281.011.MLD
# 0:15:38.605061
# Preparing zarr stores
# 0:15:39.020157
# Rechunking
# 0:15:39.251971
# Completed rechunk for LE-1281.011.MLD
# 0:16:50.303749
#
# LE-1281.012.MLD
# 0:16:54.870781
# Preparing zarr stores
# 0:16:55.370761
# Rechunking
# 0:16:55.602802
# Completed rechunk for LE-1281.012.MLD
# 0:18:06.622539
#
# LE-1281.013.MLD
# 0:18:10.823694
# Preparing zarr stores
# 0:18:11.466446
# Rechunking
# 0:18:11.707758
# Completed rechunk for LE-1281.013.MLD
# 0:19:23.671089
#
# LE-1301.011.MLD
# 0:19:28.248936
# Preparing zarr stores
# 0:19:28.949602
# Rechunking
# 0:19:29.187724
# Completed rechunk for LE-1301.011.MLD
# 0:21:04.362254
#
# LE-1301.012.MLD
# 0:21:08.729325
# Preparing zarr stores
# 0:21:09.160075
# Rechunking
# 0:21:09.392182
# Completed rechunk for LE-1301.012.MLD
# 0:22:19.841589
#
# LE-1301.013.MLD
# 0:22:24.620092
# Preparing zarr stores
# 0:22:25.278843
# Rechunking
# 0:22:25.498654
# Completed rechunk for LE-1301.013.MLD
# 0:23:41.055670
#
# PROCESS_COMPLETED
# -1 day, 23:36:14.391195
# 0

# %%
client.close()
cluster.close()

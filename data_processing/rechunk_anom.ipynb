# %% [markdown]
# # Rechunk variables
# This notebook rechunks variables for optimizing operations across the time dimension.

# %%
import os
import sys
import shutil
import warnings
import json
from datetime import datetime
from itertools import product
import numpy as np
import xarray as xr
from rechunker import rechunk
import dask
from dask_jobqueue import PBSCluster
from dask.distributed import Client

sys.path.append('..')
import utils

# %%
## Globals
with open("../paths.json") as paths_json: 
    PATHS = json.load(paths_json)
with open("../globals.json") as globals_json:
    GLOBALS = json.load(globals_json)
    
FILE  = os.path.join(os.path.abspath('.'), 'rechunk.ipynb')

VARIABLES = ['zos', 'SST', 'UBOT', 'VBOT']

# %% [markdown]
# Dask

# %%
cluster = PBSCluster(walltime='02:00:00')
client = Client(cluster)
# Out:
# $WORK/conda-envs/ml/lib/python3.8/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 46026 instead
#   warnings.warn(

# %%
cluster.scale(16)
cluster
# Out:
# PBSCluster(34ee28a7, 'tcp://10.12.206.46:41647', workers=0, threads=0, memory=0 B)

# %% [markdown]
# Functions

# %%
def rm_stores(*stores):
    for store in stores:
        if os.path.exists(store):
            shutil.rmtree(store)

def execute_rechunk(ds, target_store, temp_store):
    chunks_dict = {
        'time': 3650,
        'lat': 192,
        'lon': 288
    }
    max_mem='12GB'
    
    array_plan = rechunk(
        ds, chunks_dict, max_mem, target_store, temp_store=temp_store
    )
    
    array_plan.execute()

# %%
def main():
    START_TIME = datetime.now()
    
    for var, init_year, member in product(
            VARIABLES, GLOBALS['init_years'], GLOBALS['members']):
        print(f"LE-{init_year}.{member}.{var}_anom.zarr")
        print(datetime.now() - START_TIME)
        
        # Load data as a dataset
        ds = utils.data.load_anomalies(
            var, init_year, member, full_ds=True, chunkedby='time')
        
        # Prepare paths for rechunking
        print("Preparing zarr stores")
        print(datetime.now() - START_TIME)
        target_store = os.path.join(
            PATHS['anom_spatial'],
            f'LE2-{init_year}.{member}.{var}_anom.zarr'
        )
        temp_store = os.path.join(PATHS['tmp'],'temp.zarr')
        rm_stores(target_store, temp_store)
        
        # Rechunk
        print("Rechunking")
        print(datetime.now() - START_TIME)
        execute_rechunk(ds, target_store, temp_store)
        
        # Repeat
        print(f"Completed rechunk for LE-{init_year}.{member}.{var}_anom.zarr")
        print(datetime.now() - START_TIME, '\n')
        client.restart()
    
    print("PROCESS_COMPLETED")
    print(START_TIME - datetime.now())
    
    return 0

# %% [markdown]
# ---

# %%
main()
# Out:
# LE-1251.011.SSH_anom.zarr
# 0:00:00.000038
# Preparing zarr stores
# 0:00:00.414282
# Rechunking
# 0:00:00.699488
# Completed rechunk for LE-1251.011.SSH_anom.zarr
# 0:00:42.472053
#
# LE-1251.012.SSH_anom.zarr
# 0:00:46.032769
# Preparing zarr stores
# 0:00:46.413161
# Rechunking
# 0:00:46.841917
# Completed rechunk for LE-1251.012.SSH_anom.zarr
# 0:01:25.784396
#
# LE-1251.013.SSH_anom.zarr
# 0:01:29.049445
# Preparing zarr stores
# 0:01:29.267358
# Rechunking
# 0:01:29.679693
# Completed rechunk for LE-1251.013.SSH_anom.zarr
# 0:02:13.802062
#
# LE-1281.011.SSH_anom.zarr
# 0:02:16.050455
# Preparing zarr stores
# 0:02:16.373001
# Rechunking
# 0:02:16.789501
# Completed rechunk for LE-1281.011.SSH_anom.zarr
# 0:02:58.301318
#
# LE-1281.012.SSH_anom.zarr
# 0:03:01.190001
# Preparing zarr stores
# 0:03:01.421324
# Rechunking
# 0:03:01.831687
# Completed rechunk for LE-1281.012.SSH_anom.zarr
# 0:03:43.010779
#
# LE-1281.013.SSH_anom.zarr
# 0:03:45.651803
# Preparing zarr stores
# 0:03:46.003697
# Rechunking
# 0:03:46.405765
# Completed rechunk for LE-1281.013.SSH_anom.zarr
# 0:04:26.005402
#
# LE-1301.011.SSH_anom.zarr
# 0:04:29.071371
# Preparing zarr stores
# 0:04:29.312274
# Rechunking
# 0:04:29.748283
# Completed rechunk for LE-1301.011.SSH_anom.zarr
# 0:05:10.344327
#
# LE-1301.012.SSH_anom.zarr
# 0:05:12.823886
# Preparing zarr stores
# 0:05:13.143301
# Rechunking
# 0:05:13.533988
# Completed rechunk for LE-1301.012.SSH_anom.zarr
# 0:05:53.045885
#
# LE-1301.013.SSH_anom.zarr
# 0:05:55.511048
# Preparing zarr stores
# 0:05:55.740390
# Rechunking
# 0:05:56.127446
# Completed rechunk for LE-1301.013.SSH_anom.zarr
# 0:06:36.108879
#
# LE-1251.011.zos_anom.zarr
# 0:06:38.996453
# Preparing zarr stores
# 0:06:39.354138
# Rechunking
# 0:06:39.745444
# Completed rechunk for LE-1251.011.zos_anom.zarr
# 0:07:18.232653
#
# LE-1251.012.zos_anom.zarr
# 0:07:20.499657
# Preparing zarr stores
# 0:07:20.874853
# Rechunking
# 0:07:21.264447
# Completed rechunk for LE-1251.012.zos_anom.zarr
# 0:08:01.365670
#
# LE-1251.013.zos_anom.zarr
# 0:08:04.010240
# Preparing zarr stores
# 0:08:04.316103
# Rechunking
# 0:08:04.745139
# Completed rechunk for LE-1251.013.zos_anom.zarr
# 0:08:43.736991
#
# LE-1281.011.zos_anom.zarr
# 0:08:46.600719
# Preparing zarr stores
# 0:08:46.979839
# Rechunking
# 0:08:47.440565
# Completed rechunk for LE-1281.011.zos_anom.zarr
# 0:09:25.352493
#
# LE-1281.012.zos_anom.zarr
# 0:09:28.608747
# Preparing zarr stores
# 0:09:28.942377
# Rechunking
# 0:09:29.342043
# Completed rechunk for LE-1281.012.zos_anom.zarr
# 0:10:08.031113
#
# LE-1281.013.zos_anom.zarr
# 0:10:10.708304
# Preparing zarr stores
# 0:10:11.069214
# Rechunking
# 0:10:11.479113
# Completed rechunk for LE-1281.013.zos_anom.zarr
# 0:10:52.823461
#
# LE-1301.011.zos_anom.zarr
# 0:10:54.922153
# Preparing zarr stores
# 0:10:55.266934
# Rechunking
# 0:10:55.676080
# Completed rechunk for LE-1301.011.zos_anom.zarr
# 0:11:36.075605
#
# LE-1301.012.zos_anom.zarr
# 0:11:38.730461
# Preparing zarr stores
# 0:11:39.089438
# Rechunking
# 0:11:39.498372
# Completed rechunk for LE-1301.012.zos_anom.zarr
# 0:12:20.108131
#
# LE-1301.013.zos_anom.zarr
# 0:12:22.822464
# Preparing zarr stores
# 0:12:23.065646
# Rechunking
# 0:12:23.421165
# Completed rechunk for LE-1301.013.zos_anom.zarr
# 0:13:04.585356
#
# LE-1251.011.SST_anom.zarr
# 0:13:07.038723
# Preparing zarr stores
# 0:13:07.394403
# Rechunking
# 0:13:07.804083
# Completed rechunk for LE-1251.011.SST_anom.zarr
# 0:13:45.223999
#
# LE-1251.012.SST_anom.zarr
# 0:13:48.090605
# Preparing zarr stores
# 0:13:48.462785
# Rechunking
# 0:13:49.227894
# Completed rechunk for LE-1251.012.SST_anom.zarr
# 0:14:29.608975
#
# LE-1251.013.SST_anom.zarr
# 0:14:32.700288
# Preparing zarr stores
# 0:14:33.114957
# Rechunking
# 0:14:33.546973
# Completed rechunk for LE-1251.013.SST_anom.zarr
# 0:15:12.206893
#
# LE-1281.011.SST_anom.zarr
# 0:15:14.649687
# Preparing zarr stores
# 0:15:15.296216
# Rechunking
# 0:15:17.604804
# Completed rechunk for LE-1281.011.SST_anom.zarr
# 0:15:58.769897
#
# LE-1281.012.SST_anom.zarr
# 0:16:01.213009
# Preparing zarr stores
# 0:16:01.577509
# Rechunking
# 0:16:01.914452
# Completed rechunk for LE-1281.012.SST_anom.zarr
# 0:16:42.530192
#
# LE-1281.013.SST_anom.zarr
# 0:16:45.191860
# Preparing zarr stores
# 0:16:45.769274
# Rechunking
# 0:16:46.158335
# Completed rechunk for LE-1281.013.SST_anom.zarr
# 0:17:24.255281
#
# LE-1301.011.SST_anom.zarr
# 0:17:26.729360
# Preparing zarr stores
# 0:17:26.980073
# Rechunking
# 0:17:27.235113
# Completed rechunk for LE-1301.011.SST_anom.zarr
# 0:18:05.496385
#
# LE-1301.012.SST_anom.zarr
# 0:18:08.570849
# Preparing zarr stores
# 0:18:08.944299
# Rechunking
# 0:18:09.176350
# Completed rechunk for LE-1301.012.SST_anom.zarr
# 0:18:47.930796
#
# LE-1301.013.SST_anom.zarr
# 0:18:51.002000
# Preparing zarr stores
# 0:18:51.499897
# Rechunking
# 0:18:51.944168
# Completed rechunk for LE-1301.013.SST_anom.zarr
# 0:19:30.656111
#
# LE-1251.011.PSL_anom.zarr
# 0:19:33.932200
# Preparing zarr stores
# 0:19:34.289876
# Rechunking
# 0:19:34.550888
# Completed rechunk for LE-1251.011.PSL_anom.zarr
# 0:20:21.408031
#
# LE-1251.012.PSL_anom.zarr
# 0:20:24.068689
# Preparing zarr stores
# 0:20:24.591449
# Rechunking
# 0:20:24.930019
# Completed rechunk for LE-1251.012.PSL_anom.zarr
# 0:21:11.199610
#
# LE-1251.013.PSL_anom.zarr
# 0:21:13.292870
# Preparing zarr stores
# 0:21:13.622018
# Rechunking
# 0:21:14.038815
# Completed rechunk for LE-1251.013.PSL_anom.zarr
# 0:22:02.209487
#
# LE-1281.011.PSL_anom.zarr
# 0:22:04.482591
# Preparing zarr stores
# 0:22:05.016674
# Rechunking
# 0:22:05.947113
# Completed rechunk for LE-1281.011.PSL_anom.zarr
# 0:22:56.762962
#
# LE-1281.012.PSL_anom.zarr
# 0:22:59.253598
# Preparing zarr stores
# 0:22:59.625731
# Rechunking
# 0:22:59.864166
# Completed rechunk for LE-1281.012.PSL_anom.zarr
# 0:23:47.644283
#
# LE-1281.013.PSL_anom.zarr
# 0:23:50.332698
# Preparing zarr stores
# 0:23:50.694774
# Rechunking
# 0:23:50.928045
# Completed rechunk for LE-1281.013.PSL_anom.zarr
# 0:24:40.636590
#
# LE-1301.011.PSL_anom.zarr
# 0:24:43.135003
# Preparing zarr stores
# 0:24:43.722581
# Rechunking
# 0:24:44.098063
# Completed rechunk for LE-1301.011.PSL_anom.zarr
# 0:25:30.913334
#
# LE-1301.012.PSL_anom.zarr
# 0:25:33.389954
# Preparing zarr stores
# 0:25:34.019203
# Rechunking
# 0:25:35.030895
# Completed rechunk for LE-1301.012.PSL_anom.zarr
# 0:26:24.004648
#
# LE-1301.013.PSL_anom.zarr
# 0:26:26.652672
# Preparing zarr stores
# 0:26:27.763102
# Rechunking
# 0:26:28.273143
# Completed rechunk for LE-1301.013.PSL_anom.zarr
# 0:27:24.132020
#
# LE-1251.011.UBOT_anom.zarr
# 0:27:27.196115
# Preparing zarr stores
# 0:27:27.867133
# Rechunking
# 0:27:28.111595
# Completed rechunk for LE-1251.011.UBOT_anom.zarr
# 0:28:19.135546
#
# LE-1251.012.UBOT_anom.zarr
# 0:28:22.231183
# Preparing zarr stores
# 0:28:22.631677
# Rechunking
# 0:28:22.859232
# Completed rechunk for LE-1251.012.UBOT_anom.zarr
# 0:29:20.500901
#
# LE-1251.013.UBOT_anom.zarr
# 0:29:22.757759
# Preparing zarr stores
# 0:29:22.978199
# Rechunking
# 0:29:23.164816
# Completed rechunk for LE-1251.013.UBOT_anom.zarr
# 0:30:11.676910
#
# LE-1281.011.UBOT_anom.zarr
# 0:30:14.549116
# Preparing zarr stores
# 0:30:14.803965
# Rechunking
# 0:30:15.007477
# Completed rechunk for LE-1281.011.UBOT_anom.zarr
# 0:31:07.681069
#
# LE-1281.012.UBOT_anom.zarr
# 0:31:10.351935
# Preparing zarr stores
# 0:31:10.910119
# Rechunking
# 0:31:11.558559
# Completed rechunk for LE-1281.012.UBOT_anom.zarr
# 0:32:00.043476
#
# LE-1281.013.UBOT_anom.zarr
# 0:32:03.704015
# Preparing zarr stores
# 0:32:04.361449
# Rechunking
# 0:32:05.357036
# Completed rechunk for LE-1281.013.UBOT_anom.zarr
# 0:32:55.881953
#
# LE-1301.011.UBOT_anom.zarr
# 0:32:58.352720
# Preparing zarr stores
# 0:32:58.626926
# Rechunking
# 0:32:58.946220
# Completed rechunk for LE-1301.011.UBOT_anom.zarr
# 0:33:46.248659
#
# LE-1301.012.UBOT_anom.zarr
# 0:33:49.510101
# Preparing zarr stores
# 0:33:49.774799
# Rechunking
# 0:33:49.981128
# Completed rechunk for LE-1301.012.UBOT_anom.zarr
# 0:34:38.096329
#
# LE-1301.013.UBOT_anom.zarr
# 0:34:40.792331
# Preparing zarr stores
# 0:34:41.204053
# Rechunking
# 0:34:41.424938
# Completed rechunk for LE-1301.013.UBOT_anom.zarr
# 0:35:30.553601
#
# LE-1251.011.VBOT_anom.zarr
# 0:35:32.815336
# Preparing zarr stores
# 0:35:33.214968
# Rechunking
# 0:35:33.421990
# Completed rechunk for LE-1251.011.VBOT_anom.zarr
# 0:36:20.310066
#
# LE-1251.012.VBOT_anom.zarr
# 0:36:22.966634
# Preparing zarr stores
# 0:36:23.191266
# Rechunking
# 0:36:23.420220
# Completed rechunk for LE-1251.012.VBOT_anom.zarr
# 0:37:11.527220
#
# LE-1251.013.VBOT_anom.zarr
# 0:37:14.412608
# Preparing zarr stores
# 0:37:14.654403
# Rechunking
# 0:37:14.876794
# Completed rechunk for LE-1251.013.VBOT_anom.zarr
# 0:38:02.820753
#
# LE-1281.011.VBOT_anom.zarr
# 0:38:05.690838
# Preparing zarr stores
# 0:38:06.132974
# Rechunking
# 0:38:06.331053
# Completed rechunk for LE-1281.011.VBOT_anom.zarr
# 0:38:57.872687
#
# LE-1281.012.VBOT_anom.zarr
# 0:39:00.527949
# Preparing zarr stores
# 0:39:00.949602
# Rechunking
# 0:39:01.168718
# Completed rechunk for LE-1281.012.VBOT_anom.zarr
# 0:39:55.960631
#
# LE-1281.013.VBOT_anom.zarr
# 0:39:58.657000
# Preparing zarr stores
# 0:39:58.921286
# Rechunking
# 0:39:59.140742
# Completed rechunk for LE-1281.013.VBOT_anom.zarr
# 0:40:46.076266
#
# LE-1301.011.VBOT_anom.zarr
# 0:40:49.126448
# Preparing zarr stores
# 0:40:49.525561
# Rechunking
# 0:40:49.752499
# Completed rechunk for LE-1301.011.VBOT_anom.zarr
# 0:41:37.890781
#
# LE-1301.012.VBOT_anom.zarr
# 0:41:40.333492
# Preparing zarr stores
# 0:41:40.764013
# Rechunking
# 0:41:40.993300
# Completed rechunk for LE-1301.012.VBOT_anom.zarr
# 0:42:28.959472
#
# LE-1301.013.VBOT_anom.zarr
# 0:42:31.651278
# Preparing zarr stores
# 0:42:31.932065
# Rechunking
# 0:42:32.164005
# Completed rechunk for LE-1301.013.VBOT_anom.zarr
# 0:43:19.548634
#
# LE-1251.011.SHFLX_anom.zarr
# 0:43:22.227659
# Preparing zarr stores
# 0:43:22.862045
# Rechunking
# 0:43:23.169324
# Completed rechunk for LE-1251.011.SHFLX_anom.zarr
# 0:44:12.513139
#
# LE-1251.012.SHFLX_anom.zarr
# 0:44:15.000586
# Preparing zarr stores
# 0:44:15.643435
# Rechunking
# 0:44:15.993009
# Completed rechunk for LE-1251.012.SHFLX_anom.zarr
# 0:45:02.514700
#
# LE-1251.013.SHFLX_anom.zarr
# 0:45:04.853947
# Preparing zarr stores
# 0:45:05.335009
# Rechunking
# 0:45:05.861433
# Completed rechunk for LE-1251.013.SHFLX_anom.zarr
# 0:45:53.286828
#
# LE-1281.011.SHFLX_anom.zarr
# 0:45:55.551755
# Preparing zarr stores
# 0:45:56.042592
# Rechunking
# 0:45:56.318742
# Completed rechunk for LE-1281.011.SHFLX_anom.zarr
# 0:46:44.249915
#
# LE-1281.012.SHFLX_anom.zarr
# 0:46:47.327608
# Preparing zarr stores
# 0:46:47.778109
# Rechunking
# 0:46:48.012324
# Completed rechunk for LE-1281.012.SHFLX_anom.zarr
# 0:47:38.264097
#
# LE-1281.013.SHFLX_anom.zarr
# 0:47:40.740927
# Preparing zarr stores
# 0:47:40.960416
# Rechunking
# 0:47:41.187739
# Completed rechunk for LE-1281.013.SHFLX_anom.zarr
# 0:48:27.512160
#
# LE-1301.011.SHFLX_anom.zarr
# 0:48:29.971973
# Preparing zarr stores
# 0:48:30.495398
# Rechunking
# 0:48:30.762626
# Completed rechunk for LE-1301.011.SHFLX_anom.zarr
# 0:49:17.126593
#
# LE-1301.012.SHFLX_anom.zarr
# 0:49:19.834252
# Preparing zarr stores
# 0:49:20.488883
# Rechunking
# 0:49:20.909391
# Completed rechunk for LE-1301.012.SHFLX_anom.zarr
# 0:50:08.185944
#
# LE-1301.013.SHFLX_anom.zarr
# 0:50:11.070842
# Preparing zarr stores
# 0:50:11.340716
# Rechunking
# 0:50:11.628958
# Completed rechunk for LE-1301.013.SHFLX_anom.zarr
# 0:51:02.858917
#
# PROCESS_COMPLETED
# -1 day, 23:08:54.828771
# 0

# %%
main()
# Out:
# LE-1251.011.SHF_anom.zarr
# 0:00:00.000034
# Preparing zarr stores
# 0:00:00.245781
# Rechunking
# 0:00:00.248815
# Completed rechunk for LE-1251.011.SHF_anom.zarr
# 0:01:36.384921
#
# LE-1251.012.SHF_anom.zarr
# 0:01:46.928961
# Preparing zarr stores
# 0:01:47.181998
# Rechunking
# 0:01:47.376214
# Completed rechunk for LE-1251.012.SHF_anom.zarr
# 0:03:03.891730
#
# LE-1251.013.SHF_anom.zarr
# 0:03:07.058789
# Preparing zarr stores
# 0:03:07.478973
# Rechunking
# 0:03:07.720086
# Completed rechunk for LE-1251.013.SHF_anom.zarr
# 0:04:29.964921
#
# LE-1281.011.SHF_anom.zarr
# 0:04:33.585093
# Preparing zarr stores
# 0:04:34.037130
# Rechunking
# 0:04:34.264015
# Completed rechunk for LE-1281.011.SHF_anom.zarr
# 0:05:36.999961
#
# LE-1281.012.SHF_anom.zarr
# 0:05:40.057150
# Preparing zarr stores
# 0:05:40.297015
# Rechunking
# 0:05:40.502850
# Completed rechunk for LE-1281.012.SHF_anom.zarr
# 0:06:54.243032
#
# LE-1281.013.SHF_anom.zarr
# 0:06:57.430819
# Preparing zarr stores
# 0:06:57.697340
# Rechunking
# 0:06:57.916552
# Completed rechunk for LE-1281.013.SHF_anom.zarr
# 0:08:19.480647
#
# LE-1301.011.SHF_anom.zarr
# 0:08:23.715255
# Preparing zarr stores
# 0:08:24.169301
# Rechunking
# 0:08:24.378927
# Completed rechunk for LE-1301.011.SHF_anom.zarr
# 0:09:37.710138
#
# LE-1301.012.SHF_anom.zarr
# 0:09:41.295933
# Preparing zarr stores
# 0:09:41.748643
# Rechunking
# 0:09:41.965548
# Completed rechunk for LE-1301.012.SHF_anom.zarr
# 0:10:36.454101
#
# LE-1301.013.SHF_anom.zarr
# 0:10:44.057385
# Preparing zarr stores
# 0:10:44.292383
# Rechunking
# 0:10:44.460229
# Completed rechunk for LE-1301.013.SHF_anom.zarr
# 0:11:57.619060
#
# LE-1251.011.MLD_anom.zarr
# 0:12:00.374887
# Preparing zarr stores
# 0:12:00.811965
# Rechunking
# 0:12:01.021080
# Completed rechunk for LE-1251.011.MLD_anom.zarr
# 0:13:15.464495
#
# LE-1251.012.MLD_anom.zarr
# 0:13:18.703804
# Preparing zarr stores
# 0:13:19.196925
# Rechunking
# 0:13:19.410477
# Completed rechunk for LE-1251.012.MLD_anom.zarr
# 0:14:30.179872
#
# LE-1251.013.MLD_anom.zarr
# 0:14:33.172443
# Preparing zarr stores
# 0:14:33.393854
# Rechunking
# 0:14:33.629138
# Completed rechunk for LE-1251.013.MLD_anom.zarr
# 0:15:43.967226
#
# LE-1281.011.MLD_anom.zarr
# 0:15:47.014329
# Preparing zarr stores
# 0:15:47.447064
# Rechunking
# 0:15:47.656189
# Completed rechunk for LE-1281.011.MLD_anom.zarr
# 0:17:02.467630
#
# LE-1281.012.MLD_anom.zarr
# 0:17:05.080269
# Preparing zarr stores
# 0:17:05.503321
# Rechunking
# 0:17:05.725517
# Completed rechunk for LE-1281.012.MLD_anom.zarr
# 0:18:18.054408
#
# LE-1281.013.MLD_anom.zarr
# 0:18:20.888762
# Preparing zarr stores
# 0:18:21.135482
# Rechunking
# 0:18:21.309948
# Completed rechunk for LE-1281.013.MLD_anom.zarr
# 0:19:34.382027
#
# LE-1301.011.MLD_anom.zarr
# 0:19:37.578641
# Preparing zarr stores
# 0:19:38.006499
# Rechunking
# 0:19:38.229466
# Completed rechunk for LE-1301.011.MLD_anom.zarr
# 0:20:58.291463
#
# LE-1301.012.MLD_anom.zarr
# 0:21:01.100888
# Preparing zarr stores
# 0:21:01.572803
# Rechunking
# 0:21:01.799437
# Completed rechunk for LE-1301.012.MLD_anom.zarr
# 0:22:17.011128
#
# LE-1301.013.MLD_anom.zarr
# 0:22:24.056943
# Preparing zarr stores
# 0:22:24.268254
# Rechunking
# 0:22:24.449732
# Completed rechunk for LE-1301.013.MLD_anom.zarr
# 0:23:37.127424
#
# PROCESS_COMPLETED
# -1 day, 23:36:19.532697
# 0

# %%
client.close()
cluster.close()
